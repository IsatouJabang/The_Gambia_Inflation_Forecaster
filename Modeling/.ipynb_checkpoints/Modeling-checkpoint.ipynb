# %%
pip install xgboost scikit-learn
# Out:
# Collecting xgboost
#   Downloading xgboost-3.2.0-py3-none-macosx_10_15_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: scikit-learn in /Users/Aisha/miniconda3/envs/myenv/lib/python3.10/site-packages (1.7.1)
# Requirement already satisfied: numpy in /Users/Aisha/miniconda3/envs/myenv/lib/python3.10/site-packages (from xgboost) (2.0.1)
# Requirement already satisfied: scipy in /Users/Aisha/miniconda3/envs/myenv/lib/python3.10/site-packages (from xgboost) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/Aisha/miniconda3/envs/myenv/lib/python3.10/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/Aisha/miniconda3/envs/myenv/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Downloading xgboost-3.2.0-py3-none-macosx_10_15_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 351.8 kB/s  0:00:07 eta 0:00:01
# Installing collected packages: xgboost
# Successfully installed xgboost-3.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import xgboost as xgb
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# %%
# Load our processed data
df = pd.read_csv("Gambia_Inflation_ML_Master_Matrix.csv")
df['Date'] = pd.to_datetime(df['Date'])
